# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

import keras
from keras.layers import Dense
from keras.models import Sequential

dataset = pd.read_csv('sat.csv')
dataset
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
x = dataset.iloc[:,[0]].values
x
# Out:
# array([[1714],
#        [1664],
#        [1760],
#        [1685],
#        [1693],
#        [1670],
#        [1764],
#        [1764],
#        [1792],
#        [1850],
#        [1735],
#        [1775],
#        [1735],
#        [1712],
#        [1773],
#        [1872],
#        [1755],
#        [1674],
#        [1842],
#        [1786],
#        [1761],
#        [1722],
#        [1663],
#        [1687],
#        [1974],
#        [1826],
#        [1787],
#        [1821],
#        [2020],
#        [1794],
#        [1769],
#        [1934],
#        [1775],
#        [1855],
#        [1880],
#        [1849],
#        [1808],
#        [1954],
#        [1777],
#        [1831],
#        [1865],
#        [1850],
#        [1966],
#        [1702],
#        [1990],
#        [1925],
#        [1824],
#        [1956],
#        [1857],
#        [1979],
#        [1802],
#        [1855],
#        [1907],
#        [1634],
#        [1879],
#        [1887],
#        [1730],
#        [1953],
# ...

# %%
y = dataset.iloc[:,1].values
y
# Out:
# array([2.4 , 2.52, 2.54, 2.74, 2.83, 2.91, 3.  , 3.  , 3.01, 3.01, 3.02,
#        3.07, 3.08, 3.08, 3.12, 3.17, 3.17, 3.17, 3.17, 3.19, 3.19, 3.19,
#        3.2 , 3.21, 3.24, 3.28, 3.28, 3.28, 3.28, 3.28, 3.28, 3.28, 3.29,
#        3.29, 3.29, 3.31, 3.32, 3.34, 3.37, 3.37, 3.37, 3.38, 3.38, 3.39,
#        3.39, 3.4 , 3.4 , 3.4 , 3.41, 3.41, 3.41, 3.42, 3.42, 3.42, 3.44,
#        3.47, 3.47, 3.47, 3.47, 3.48, 3.49, 3.49, 3.5 , 3.51, 3.51, 3.52,
#        3.52, 3.54, 3.58, 3.58, 3.59, 3.59, 3.6 , 3.6 , 3.61, 3.62, 3.64,
#        3.65, 3.71, 3.71, 3.71, 3.73, 3.76, 3.81])

# %%
plt.scatter(x,y)
plt.xlabel('SAT')
plt.ylabel('Gpa')
plt.show()

# %%
model = Sequential([Dense(10,activation='relu',input_shape=[1]),
                   Dense(10,activation='relu'),
                   Dense(10,activation='relu'),
                   Dense(1,activation='linear')])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 10)                20
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# ...
# Total params: 251
# Trainable params: 251
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="mean_squared_error",optimizer="sgd")
model.fit(x,y,epochs=200)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 1s 2ms/step - loss: inf
# Epoch 2/200
# 3/3 [==============================] - 0s 4ms/step - loss: nan
# Epoch 3/200
# 3/3 [==============================] - 0s 3ms/step - loss: nan
# Epoch 4/200
# 3/3 [==============================] - 0s 3ms/step - loss: nan
# Epoch 5/200
# 3/3 [==============================] - 0s 3ms/step - loss: nan
# Epoch 6/200
# 3/3 [==============================] - 0s 3ms/step - loss: nan
# Epoch 7/200
# 3/3 [==============================] - 0s 3ms/step - loss: nan
# Epoch 8/200
# 3/3 [==============================] - 0s 3ms/step - loss: nan
# Epoch 9/200
# 3/3 [==============================] - 0s 4ms/step - loss: nan
# Epoch 10/200
# 3/3 [==============================] - 0s 3ms/step - loss: nan
# Epoch 11/200
# 3/3 [==============================] - 0s 3ms/step - loss: nan
# Epoch 12/200
# 3/3 [==============================] - 0s 3ms/step - loss: nan
# Epoch 13/200
# ...

# %%
model1 = Sequential([Dense(10,activation='relu',input_shape=[1],kernel_regularizer=keras.regularizers.l1_l2(1),kernel_initializer="he_uniform"),
                   Dense(10,activation='relu',kernel_initializer="he_uniform"),
                   Dense(10,activation='relu',kernel_initializer="he_uniform"),
                   Dense(1,activation='linear')])

# %%
model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 10)                20
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 11
# ...
# Total params: 251
# Trainable params: 251
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = keras.optimizers.rmsprop_v2.RMSProp(learning_rate=0.1)
model.compile(loss="mean_squared_error",optimizer=optimizer)

# %%
model.fit(x,y,epochs=1000)
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 1s 3ms/step - loss: nan
# Epoch 2/1000
# 3/3 [==============================] - 0s 3ms/step - loss: nan
# Epoch 3/1000
# 3/3 [==============================] - 0s 4ms/step - loss: nan
# Epoch 4/1000
# 3/3 [==============================] - 0s 3ms/step - loss: nan
# Epoch 5/1000
# 3/3 [==============================] - 0s 3ms/step - loss: nan
# Epoch 6/1000
# 3/3 [==============================] - 0s 4ms/step - loss: nan
# Epoch 7/1000
# 3/3 [==============================] - 0s 5ms/step - loss: nan
# Epoch 8/1000
# 3/3 [==============================] - 0s 4ms/step - loss: nan
# Epoch 9/1000
# 3/3 [==============================] - 0s 3ms/step - loss: nan
# Epoch 10/1000
# 3/3 [==============================] - 0s 4ms/step - loss: nan
# Epoch 11/1000
# 3/3 [==============================] - 0s 4ms/step - loss: nan
# Epoch 12/1000
# 3/3 [==============================] - 0s 5ms/step - loss: nan
# Epoch 13/1000
# ...

# %%
plt.scatter(x,y)
plt.plot(x,model.predict(x),color='green')
plt.xlabel('SAT')
plt.ylabel('Gpa')
plt.show()
